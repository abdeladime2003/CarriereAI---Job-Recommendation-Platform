# %%
import pandas as pd

# %%
df = pd.read_csv('job_offers.csv')

# %%
df["competences"][0]
# Out:
# '[{\'code\': \'116780\', \'libelle\': "Procédures d\'entretien de bâtiments agricoles", \'exigence\': \'S\'}, {\'code\': \'100011\', \'libelle\': \'Techniques culturales\', \'exigence\': \'S\'}, {\'code\': \'122854\', \'libelle\': \'Techniques de fauchage\', \'exigence\': \'S\'}, {\'code\': \'300440\', \'libelle\': \'Animer, coordonner une équipe\', \'exigence\': \'S\'}, {\'code\': \'122853\', \'libelle\': \'Récolter un produit à maturité et selon les consignes de calibrage\', \'exigence\': \'S\'}]'
